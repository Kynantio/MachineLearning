# %% [markdown]
# <a href="https://colab.research.google.com/github/Kynantio/MachineLearning/blob/main/Jobsheet_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jobsheet 11 Machine Learning
# ### Kynantio Candra Abrari
# ### 2141720206 / 3A / 16

# %% [markdown]
# # Praktikum 1

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/Polinema/Machine Learning/Jobsheet 11/dataset.zip', 'r') as zipobj:
  zipobj.extractall('/content/drive/MyDrive/Polinema/Machine Learning')

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Polinema/Machine Learning/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Polinema/Machine Learning/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 42s 143ms/step - loss: 0.6606 - accuracy: 0.5934 - val_loss: 0.6161 - val_accuracy: 0.6775
# Epoch 2/25
# 250/250 [==============================] - 36s 142ms/step - loss: 0.5866 - accuracy: 0.6876 - val_loss: 0.5563 - val_accuracy: 0.7080
# Epoch 3/25
# 250/250 [==============================] - 38s 150ms/step - loss: 0.5439 - accuracy: 0.7234 - val_loss: 0.5322 - val_accuracy: 0.7340
# Epoch 4/25
# 250/250 [==============================] - 36s 144ms/step - loss: 0.5152 - accuracy: 0.7398 - val_loss: 0.5357 - val_accuracy: 0.7320
# Epoch 5/25
# 250/250 [==============================] - 39s 157ms/step - loss: 0.4926 - accuracy: 0.7594 - val_loss: 0.5040 - val_accuracy: 0.7505
# Epoch 6/25
# 250/250 [==============================] - 37s 147ms/step - loss: 0.4699 - accuracy: 0.7769 - val_loss: 0.6238 - val_accuracy: 0.7045
# Epoch 7/25
# 250/250 [==============================] - 36s 142ms/step - loss: 0.4658 - accuracy: 0.7782 - val_loss: 0.4794 - val_accuracy: 0.7815
# Epoch 8/25
# 250/250 [==============================] - 36s 143ms/step - loss: 0.4394 - accuracy: 0.7916 - val_loss: 0.4885 - val_accuracy: 0.7790
# Epoch 9/25
# 250/250 [==============================] - 36s 144ms/step - loss: 0.4310 - accuracy: 0.7966 - val_loss: 0.5237 - val_accuracy: 0.7610
# Epoch 10/25
# 250/250 [==============================] - 36s 144ms/step - loss: 0.4163 - accuracy: 0.8083 - val_loss: 0.4672 - val_accuracy: 0.7930
# Epoch 11/25
# 250/250 [==============================] - 36s 146ms/step - loss: 0.4040 - accuracy: 0.8166 - val_loss: 0.4980 - val_accuracy: 0.7760
# Epoch 12/25
# 250/250 [==============================] - 36s 143ms/step - loss: 0.4009 - accuracy: 0.8156 - val_loss: 0.4646 - val_accuracy: 0.7935
# Epoch 13/25
# 250/250 [==============================] - 37s 147ms/step - loss: 0.3815 - accuracy: 0.8238 - val_loss: 0.4627 - val_accuracy: 0.7950
# Epoch 14/25
# 250/250 [==============================] - 36s 143ms/step - loss: 0.3786 - accuracy: 0.8313 - val_loss: 0.4501 - val_accuracy: 0.8000
# Epoch 15/25
# 250/250 [==============================] - 41s 166ms/step - loss: 0.3590 - accuracy: 0.8363 - val_loss: 0.4660 - val_accuracy: 0.7935
# Epoch 16/25
# 250/250 [==============================] - 36s 145ms/step - loss: 0.3540 - accuracy: 0.8416 - val_loss: 0.4525 - val_accuracy: 0.8090
# Epoch 17/25
# 250/250 [==============================] - 36s 145ms/step - loss: 0.3465 - accuracy: 0.8476 - val_loss: 0.4633 - val_accuracy: 0.7990
# Epoch 18/25
# 250/250 [==============================] - 36s 145ms/step - loss: 0.3244 - accuracy: 0.8576 - val_loss: 0.5176 - val_accuracy: 0.7795
# Epoch 19/25
# 250/250 [==============================] - 37s 147ms/step - loss: 0.3098 - accuracy: 0.8618 - val_loss: 0.4835 - val_accuracy: 0.7940
# Epoch 20/25
# 250/250 [==============================] - 36s 144ms/step - loss: 0.2964 - accuracy: 0.8723 - val_loss: 0.4688 - val_accuracy: 0.7935
# Epoch 21/25
# 250/250 [==============================] - 36s 145ms/step - loss: 0.2925 - accuracy: 0.8751 - val_loss: 0.5065 - val_accuracy: 0.7840
# Epoch 22/25
# 250/250 [==============================] - 36s 146ms/step - loss: 0.2830 - accuracy: 0.8781 - val_loss: 0.4957 - val_accuracy: 0.8020
# Epoch 23/25
# 250/250 [==============================] - 36s 142ms/step - loss: 0.2756 - accuracy: 0.8809 - val_loss: 0.4936 - val_accuracy: 0.7955
# Epoch 24/25
# 250/250 [==============================] - 36s 145ms/step - loss: 0.2544 - accuracy: 0.8913 - val_loss: 0.5102 - val_accuracy: 0.7950
# Epoch 25/25
# 250/250 [==============================] - 36s 143ms/step - loss: 0.2455 - accuracy: 0.8979 - val_loss: 0.5251 - val_accuracy: 0.7955

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/Polinema/Machine Learning/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 292ms/step

# %% [markdown]
# # Praktikum 2

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
import matplotlib.pyplot as plt

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])

plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56320 (220.00 KB)
# Trainable params: 56320 (220.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 64)                65600
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 12s 6ms/step - loss: 1.5312 - accuracy: 0.4428 - val_loss: 1.2479 - val_accuracy: 0.5496
# Epoch 2/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.1682 - accuracy: 0.5853 - val_loss: 1.1217 - val_accuracy: 0.6010
# Epoch 3/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0118 - accuracy: 0.6418 - val_loss: 1.1031 - val_accuracy: 0.6166
# Epoch 4/10
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.9183 - accuracy: 0.6773 - val_loss: 0.9309 - val_accuracy: 0.6691
# Epoch 5/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8500 - accuracy: 0.7019 - val_loss: 0.9210 - val_accuracy: 0.6850
# Epoch 6/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7896 - accuracy: 0.7251 - val_loss: 0.8676 - val_accuracy: 0.6996
# Epoch 7/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7381 - accuracy: 0.7416 - val_loss: 0.9143 - val_accuracy: 0.6822
# Epoch 8/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6922 - accuracy: 0.7576 - val_loss: 0.8747 - val_accuracy: 0.6971
# Epoch 9/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6584 - accuracy: 0.7691 - val_loss: 0.8672 - val_accuracy: 0.7060
# Epoch 10/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6177 - accuracy: 0.7847 - val_loss: 0.8581 - val_accuracy: 0.7130

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.8581 - accuracy: 0.7130 - 667ms/epoch - 2ms/step

# %%
print(test_acc)
# Out:
# 0.7129999995231628

# %% [markdown]
# # Tugas
# - Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.
# - Buatlah model CNN untuk klasifikasi dataset MNIST.

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from PIL import Image

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('Training set shape:', X_train.shape)
print('Test set shape:', X_test.shape)
# Out:
# Training set shape: (50000, 32, 32, 3)
# Test set shape: (10000, 32, 32, 3)

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
def cnn_model():
    model = Sequential()
    # First Conv layer
    model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4), input_shape=(32,32,3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Second Conv layer
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Third, fourth, fifth convolution layer
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Fully Connected layers
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(10, activation='softmax'))

    model.summary()
    return model

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)

# %%
model = cnn_model()
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0003),
    metrics=['accuracy']
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 32, 32, 128)       3584
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)         1179904
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten_2 (Flatten)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 512)               2097664
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense
# Epoch 36/50
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6756 - accuracy: 0.8177 - val_loss: 0.6309 - val_accuracy: 0.8303
# Epoch 37/50
# 625/625 [==============================] - 31s 50ms/step - loss: 0.6712 - accuracy: 0.8206 - val_loss: 0.6554 - val_accuracy: 0.8228
# Epoch 38/50
# 625/625 [==============================] - 31s 49ms/step - loss: 0.6724 - accuracy: 0.8205 - val_loss: 0.6519 - val_accuracy: 0.8229
# Epoch 39/50
# 625/625 [==============================] - 32s 52ms/step - loss: 0.6673 - accuracy: 0.8236 - val_loss: 0.6746 - val_accuracy: 0.8183
# Epoch 40/50
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6648 - accuracy: 0.8249 - val_loss: 0.6851 - val_accuracy: 0.8164
# Epoch 41/50
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6540 - accuracy: 0.8303 - val_loss: 0.6473 - val_accuracy: 0.8336
# Epoch 42/50
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6529 - accuracy: 0.8294 - val_loss: 0.6981 - val_accuracy: 0.8152
# Epoch 43/50
# 625/625 [==============================] - 31s 49ms/step - loss: 0.6491 - accuracy: 0.8311 - val_loss: 0.6254 - val_accuracy: 0.8399
# Epoch 44/50
# 625/625 [==============================] - 31s 50ms/step - loss: 0.6407 - accuracy: 0.8357 - val_loss: 0.6256 - val_accuracy: 0.8457
# Epoch 45/50
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6444 - accuracy: 0.8337 - val_loss: 0.7103 - val_accuracy: 0.8139
# Epoch 46/50
# 625/625 [==============================] - 31s 49ms/step - loss: 0.6388 - accuracy: 0.8375 - val_loss: 0.6268 - val_accuracy: 0.8391
# Epoch 47/50
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6308 - accuracy: 0.8402 - val_loss: 0.6367 - val_accuracy: 0.8418
# Epoch 48/50
# 625/625 [==============================] - 31s 50ms/step - loss: 0.6293 - accuracy: 0.8391 - val_loss: 0.6376 - val_accuracy: 0.8384
# Epoch 49/50
# 625/625 [==============================] - 32s 50ms/step - loss: 0.6250 - accuracy: 0.8419 - val_loss: 0.6260 - val_accuracy: 0.8453
# Epoch 50/50
# 625/625 [==============================] - 31s 50ms/step - loss: 0.6225 - accuracy: 0.8438 - val_loss: 0.6010 - val_accuracy: 0.8521

# %%
scores = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6048 - accuracy: 0.8482

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
scores = model.evaluate(X_test, y_test)
pred = model.predict(X_test)
labels = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)
errors = y_pred - y_true != 0
print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6048 - accuracy: 0.8482
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1000
#            1       0.93      0.94      0.94      1000
#            2       0.79      0.79      0.79      1000
#            3       0.76      0.59      0.67      1000
#            4       0.80      0.85      0.83      1000
#            5       0.76      0.78      0.77      1000
#            6       0.84      0.93      0.88      1000
#            7       0.89      0.88      0.89      1000
#            8       0.91      0.94      0.92      1000
#            9       0.91      0.90      0.91      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %%
fig, axes = plt.subplots(5, 5, figsize=(12,12))
axes = axes.ravel()
for i in np.arange(25):
    axes[i].imshow(X_test[i])
    axes[i].set_title('True: %s \nPredict: %s' % (labels[y_true[i]], labels[y_pred[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Memuat dataset MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Normalisasi gambar ke rentang [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Perbaikan: Mengimpor to_categorical dari tensorflow.keras.utils
from tensorflow.keras.utils import to_categorical

# Mengonversi label ke format one-hot encoding
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %%
# Menampilkan informasi tentang dataset
print("Jumlah data latihan:", len(train_images))
print("Jumlah data pengujian:", len(test_images))
print("Ukuran gambar:", train_images[0].shape)
# Out:
# Jumlah data latihan: 60000
# Jumlah data pengujian: 10000
# Ukuran gambar: (28, 28)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Membangun model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %%
# Mengompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 26, 26, 32)        320
#
#  max_pooling2d_7 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 64)        18496
#
#  max_pooling2d_8 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1600)              0
#
#  dense_8 (Dense)             (None, 128)               204928
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 232650 (908.79 KB)
# Trainable params: 232650 (908.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Melatih model
history = model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/10
# 329/329 - 4s - loss: 0.3612 - accuracy: 0.8879 - val_loss: 0.0873 - val_accuracy: 0.9739 - 4s/epoch - 13ms/step
# Epoch 2/10
# 329/329 - 3s - loss: 0.1019 - accuracy: 0.9695 - val_loss: 0.0603 - val_accuracy: 0.9819 - 3s/epoch - 10ms/step
# Epoch 3/10
# 329/329 - 3s - loss: 0.0713 - accuracy: 0.9788 - val_loss: 0.0515 - val_accuracy: 0.9849 - 3s/epoch - 9ms/step
# Epoch 4/10
# 329/329 - 2s - loss: 0.0537 - accuracy: 0.9840 - val_loss: 0.0473 - val_accuracy: 0.9863 - 2s/epoch - 6ms/step
# Epoch 5/10
# 329/329 - 2s - loss: 0.0435 - accuracy: 0.9869 - val_loss: 0.0434 - val_accuracy: 0.9875 - 2s/epoch - 6ms/step
# Epoch 6/10
# 329/329 - 2s - loss: 0.0411 - accuracy: 0.9874 - val_loss: 0.0497 - val_accuracy: 0.9854 - 2s/epoch - 6ms/step
# Epoch 7/10
# 329/329 - 2s - loss: 0.0360 - accuracy: 0.9899 - val_loss: 0.0428 - val_accuracy: 0.9883 - 2s/epoch - 5ms/step
# Epoch 8/10
# 329/329 - 2s - loss: 0.0272 - accuracy: 0.9916 - val_loss: 0.0395 - val_accuracy: 0.9884 - 2s/epoch - 6ms/step
# Epoch 9/10
# 329/329 - 2s - loss: 0.0243 - accuracy: 0.9930 - val_loss: 0.0429 - val_accuracy: 0.9892 - 2s/epoch - 6ms/step
# Epoch 10/10
# 329/329 - 2s - loss: 0.0224 - accuracy: 0.9930 - val_loss: 0.0433 - val_accuracy: 0.9894 - 2s/epoch - 6ms/step

# %%
import matplotlib.pyplot as plt

# Plot sejarah pelatihan
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Pelatihan')
plt.plot(history.history['val_accuracy'], label='Akurasi Validasi')
plt.legend(loc='lower right')
plt.title('Akurasi Pelatihan dan Validasi')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Pelatihan')
plt.plot(history.history['val_loss'], label='Loss Validasi')
plt.legend(loc='upper right')
plt.title('Loss Pelatihan dan Validasi')

plt.show()

# %%
# Evaluasi model pada kumpulan data uji
validation_loss, validation_accuracy = model.evaluate(test_images, test_labels, verbose=False)
print("Loss Validasi:", validation_loss)
print("Akurasi Validasi:", validation_accuracy)
# Out:
# Loss Validasi: 0.03195711225271225
# Akurasi Validasi: 0.9907000064849854

# %%
# Menghasilkan nilai prediksi pada kumpulan data uji
y_pred_enc = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Mendekode nilai prediksi
y_pred = [np.argmax(i) for i in y_pred_enc]

# %%
# Menampilkan laporan klasifikasi
print(classification_report(np.argmax(test_labels, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       980
#            1       1.00      0.99      1.00      1135
#            2       0.98      1.00      0.99      1032
#            3       0.98      1.00      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.99      0.98      0.99       892
#            6       0.99      0.99      0.99       958
#            7       1.00      0.98      0.99      1028
#            8       1.00      0.98      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Membuat matriks konfusi dan menampilkannya dengan heatmap
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(confusion_matrix(np.argmax(test_labels, axis=1), y_pred), annot=True, cbar=False, fmt='1d', cmap='Blues', ax=ax)
ax.set_title('Matriks Konfusi', loc='left', fontsize=16)
ax.set_xlabel('Prediksi')
ax.set_ylabel('Aktual')
# Out:
# Text(58.222222222222214, 0.5, 'Aktual')

# %%
# Menampilkan target yang diprediksi pada setiap gambar
# (label di atas gambar adalah label yang diprediksi)
plt.figure(figsize=(14, 8))
for ind, row in enumerate(test_images[:15]):
    plt.subplot(3, 5, ind+1)
    plt.title(y_pred[ind])
    img = row.reshape(28, 28)
    plt.axis('off')
    plt.imshow(img, cmap='cividis')
